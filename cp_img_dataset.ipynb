# %% [markdown]
# <a href="https://colab.research.google.com/github/vasanana/Image-Dataset/blob/main/cp_img_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bing-image-downloader

# %%
# !mkdir img_dataset

# %%
#download img
from bing_image_downloader import downloader

downloader.download('kue awuk-awuk', limit=30, output_dir='img_dataset', adult_filter_off=True)
# Out:
# [%] Downloading Images to /content/img_dataset/kue awuk-awuk
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 30 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://ksmtour.com/media/images/articles22/kue-awuk-awuk-khas-jawa-tengah.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://i.ytimg.com/vi/cRwr4nQbmxg/maxresdefault.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://img-global.cpcdn.com/recipes/3b748a42420f25fe/751x532cq70/kue-awuk-awuk-tepung-ketan-foto-resep-utama.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://i.ytimg.com/vi/h8llxDouyr4/maxresdefault.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://img-global.cpcdn.com/recipes/18e4f391480f9d0b/1200x630cq70/photo.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://i.pinimg.com/originals/3a/bb/49/3abb491ee2be6eeb7c5a71b2e5585561.jpg
# [%] File Downloaded !
#
# ...

# %%
#delete
import shutil
shutil.rmtree("/content/img_dataset/kue wajik kletik")

# %%
#download to local
# !zip -r '/content/img_dataset.zip' '/content/img_dataset'
# Out:
#   adding: content/img_dataset/ (stored 0%)
#   adding: content/img_dataset/kue apem tradisional/ (stored 0%)
#   adding: content/img_dataset/kue apem tradisional/Image_11.jpg (deflated 0%)
#   adding: content/img_dataset/kue apem tradisional/Image_14.jpg (deflated 0%)
#   adding: content/img_dataset/kue apem tradisional/Image_4.jpg (deflated 0%)
#   adding: content/img_dataset/kue apem tradisional/Image_17.jpg (deflated 0%)
#   adding: content/img_dataset/kue apem tradisional/Image_2.jpg (deflated 1%)
#   adding: content/img_dataset/kue apem tradisional/Image_23.jpg (deflated 1%)
#   adding: content/img_dataset/kue apem tradisional/Image_24.jpg (deflated 0%)
#   adding: content/img_dataset/kue apem tradisional/Image_10.jpg (deflated 0%)
#   adding: content/img_dataset/kue apem tradisional/Image_20.jpg (deflated 0%)
#   adding: content/img_dataset/kue apem tradisional/Image_16.jpg (deflated 0%)
#   adding: content/img_dataset/kue apem tradisional/Image_27.jpg (deflated 1%)
# ...
